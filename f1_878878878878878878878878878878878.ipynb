# %%
import pandas as pd
from pyecharts import options as opts
from pyecharts.charts import Tree,TreeMap,Sunburst
import json
import time

# %%
#IMDb数据集的数据在imdb.tsv中，请编写程序实现标题类型（字符串）和类型（字符串数组）-包括与标题相关的类型的TREE的可视化
#第一步  读取数据
stime = time.time()
data = pd.read_csv('imdb.tsv', sep='\t')
print("Time for reading: ", time.time()-stime, 's')
# Out:
# Time for reading:  0.24462461471557617 s

# %%
#第二步  数据格式整理
data = data[['tconst', 'titleType', 'primaryTitle', 'genres']]
data = data.dropna(subset=['titleType', 'primaryTitle', 'genres'])

stime = time.time()
#构建字典
data_tree = {}
data_treemap = {}
for _, row in data.iterrows():
    titleType = row['titleType']
    PrimaryTitle = row['primaryTitle']
    genres= set(row['genres'].split(','))
    genres_ForMap = {}.fromkeys(row['genres'].split(','), 1)
    if titleType not in data_tree:
        data_tree[titleType] = genres
    else:
        data_tree[titleType].update(set(genres))
    if titleType not in data_treemap:
        data_treemap[titleType] = genres_ForMap
    else:
        for k in set(genres_ForMap.keys())|set(data_treemap[titleType].keys()):
            data_treemap[titleType][k]=genres_ForMap.get(k, 0) + data_treemap[titleType].get(k, 0)
print("Time for category: ", time.time()-stime, 's')
# Out:
# Time for category:  19.050490856170654 s

# %%
#第三步  构建树结构数据
stime = time.time()
treeData = [{'name': 'All', 'children':[]}]
for tt,gen in data_tree.items():
    node = {'name' : tt, 'children': [{'name': genre} for genre in gen if genre != '\\N']}
    treeData[0]["children"].append(node)
    
treemapData = [{'name': 'All', 'children':[]}]
sunburstData = []
for tt, gen in data_treemap.items():
    node = {
        'name':tt,
        'children': [{'name':k, 'value':v} for k, v in gen.items() if k != '\\N']
    }
    treemapData[0]['children'].append(node)
    sunburstData.append(node)

    
print('Time for building tree: ', time.time()-stime, 's')
# Out:
# Time for building tree:  0.0019230842590332031 s

# %%
#第四步  创建树可视化函数（参数在字典格式中包含treedata,layout,orient,initialTreeDepth）
def buildTree(title, treeData, layout='orthogonal', orient='LR', initialTreeDepth=1):
    tree = (Tree(
                     init_opts=opts.InitOpts(height='850px')
                ).add('', treeData)
                 .set_global_opts(title_opts=opts.TitleOpts(title=title))
                 .set_series_opts(
                     layout=layout,
                     orient=orient,
                     collaps_interval=2,
                     collapsible=True,
                     initialTreeDepth=initialTreeDepth
                 )
           )
    
    return tree

# %%
#第五步  可视化树，请注意jupyter的可视化方式不一样
buildTree('IMDB-Tree', treeData).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e2bce803d8e34aba80880f9b750a3dd8" style="width:900px; height:850px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e2bce803d8e34aba80880f9b750a3dd8 = echarts.init(
#                     document.getElementById('e2bce803d8e34aba80880f9b750a3dd8'), 'white', {renderer: 'canvas'});
#                 var option_e2bce803d8e34aba80880f9b750a3dd8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "tree",
#             "data": [
#                 {
#                     "name": "All",
#                     "children": [
#                         {
#                             "name": "short",
#                             "children": [
#                                 {
#                                     "name": "Family"
#                                 },
#                                 {
#                                     "name": "Short"
#                                 },
#                                 {
#                                     "name": "Animation"
#                                 },
#                                 {
#                                     "name": "Romance"
#                                 },
#                                 {
#                                     "name": "Action"
#                                 },
#                                 {
#                                     "name": "Film-Noir"
#                                 },
#                                 {
#                                     "name": "History"
#                                 },
#                                 {
#                                     "name": "War"
#                                 },
#                                 {
#                                     "name": "Biography"
#                                 },
#                                 {
#                                     "name": "Music"
#                                 },
#                                 {
#                                     "name": "Crime"
#                                 },
#                                 {
#                                     "name": "Mystery"
#                                 },
#                                 {
#                                     "name": "Sci-Fi"
#                                 },
#                                 {
#                                     "name": "Thriller"
#                                 },
#                                 {
#                                     "name": "Adventure"
#                                 },
#                                 {
#                                     "name": "Musical"
#                                 },
#                                 {
#                                     "name": "Fantasy"
#                                 },
#                                 {
#                                     "name": "Western"
#                                 },
#                                 {
#                                     "name": "Horror"
#                                 },
#                                 {
#                                     "name": "Comedy"
#                                 },
#                                 {
#                                     "name": "Documentary"
#                                 },
#                                 {
#                                     "name": "Sport"
#                                 },
#                                 {
#                                     "name": "Adult"
#                                 },
#                                 {
#                                     "name": "Drama"
#                                 },
#                                 {
#                                     "name": "News"
#                                 }
#                             ]
#                         },
#                         {
#                             "name": "movie",
#                             "children": [
#                                 {
#                                     "name": "Reality-TV"
#                                 },
#                                 {
#                                     "name": "Family"
#                                 },
#                                 {
#                                     "name": "Animation"
#                                 },
#                                 {
#                                     "name": "Action"
#                                 },
#                                 {
#                                     "name": "Romance"
#                                 },
#                                 {
#                                     "name": "Talk-Show"
#                                 },
#                                 {
#                                     "name": "Film-Noir"
#                                 },
#                                 {
#                                     "name": "History"
#                                 },
#                                 {
#                                     "name": "War"
#                                 },
#                                 {
#                                     "name": "Biography"
#                                 },
#                                 {
#                                     "name": "Crime"
#                                 },
#                                 {
#                                     "name": "Sci-Fi"
#                                 },
#                                 {
#                                     "name": "Thriller"
#                                 },
#                                 {
#                                     "name": "Mystery"
#                                 },
#                                 {
#                                     "name": "Music"
#                                 },
#                                 {
#                                     "name": "Adventure"
#                                 },
#                                 {
#                                     "name": "Musical"
#                                 },
#                                 {
#                                     "name": "Fantasy"
#                                 },
#                                 {
#                                     "name": "Western"
#                                 },
#                                 {
#                                     "name": "Horror"
#                                 },
#                                 {
#                                     "name": "Comedy"
#                                 },
#                                 {
#                                     "name": "Documentary"
#                                 },
#                                 {
#                                     "name": "Sport"
#                                 },
#                                 {
#                                     "name": "Adult"
#                                 },
#                                 {
#                                     "name": "Drama"
#                                 },
#                                 {
#                                     "name": "News"
#                                 }
#                             ]
#                         },
#                         {
#                             "name": "tvShort",
#                             "children": [
#                                 {
#                                     "name":

# %%
#构建树图函数
def buildTreeMap(title, data):
    treemap = (
        TreeMap()
            .add(
                'IMDB', data,
                levels=[
                    opts.TreeMapLevelsOpts(
                        treemap_itemstyle_opts=opts.TreeMapItemStyleOpts(
                            border_color="#555", border_width=4, gap_width=4
                        )
                    ),
                    opts.TreeMapLevelsOpts(
                        color_saturation=[0.3, 0.6],
                        treemap_itemstyle_opts=opts.TreeMapItemStyleOpts(
                            border_color_saturation=0.7, gap_width=2, border_width=2
                        )
                    ),  
                    opts.TreeMapLevelsOpts(
                        color_saturation=[0.3, 0.5],
                        treemap_itemstyle_opts=opts.TreeMapItemStyleOpts(
                            border_color_saturation=0.6, gap_width=1
                        )
                    ),  
                    opts.TreeMapLevelsOpts(
                        color_saturation=[0.3, 0.5]
                    ),
                ]
            )
            .set_global_opts(title_opts=opts.TitleOpts(title=title))
        )
    
    return treemap

# %%
#第六步  可视化树图，请注意jupyter的可视化方式不一样
buildTreeMap('IMDB-Treemap', treemapData).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="39934207de9047218556cc1e20e0836a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_39934207de9047218556cc1e20e0836a = echarts.init(
#                     document.getElementById('39934207de9047218556cc1e20e0836a'), 'white', {renderer: 'canvas'});
#                 var option_39934207de9047218556cc1e20e0836a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "treemap",
#             "name": "IMDB",
#             "data": [
#                 {
#                     "name": "All",
#                     "children": [
#                         {
#                             "name": "short",
#                             "children": [
#                                 {
#                                     "name": "Documentary",
#                                     "value": 1962
#                                 },
#                                 {
#                                     "name": "Short",
#                                     "value": 12675
#                                 },
#                                 {
#                                     "name": "Animation",
#                                     "value": 4063
#                                 },
#                                 {
#                                     "name": "Comedy",
#                                     "value": 6886
#                                 },
#                                 {
#                                     "name": "Romance",
#                                     "value": 514
#                                 },
#                                 {
#                                     "name": "Sport",
#                                     "value": 82
#                                 },
#                                 {
#                                     "name": "News",
#                                     "value": 19
#                                 },
#                                 {
#                                     "name": "Drama",
#                                     "value": 2501
#                                 },
#                                 {
#                                     "name": "Fantasy",
#                                     "value": 201
#                                 },
#                                 {
#                                     "name": "Horror",
#                                     "value": 128
#                                 },
#                                 {
#                                     "name": "Biography",
#                                     "value": 78
#                                 },
#                                 {
#                                     "name": "Music",
#                                     "value": 265
#                                 },
#                                 {
#                                     "name": "War",
#                                     "value": 285
#                                 },
#                                 {
#                                     "name": "Crime",
#                                     "value": 233
#                                 },
#                                 {
#                                     "name": "Western",
#                                     "value": 755
#                                 },
#                                 {
#                                     "name": "Family",
#                                     "value": 2314
#                                 },
#                                 {
#                                     "name": "Adventure",
#                                     "value": 303
#                                 },
#                                 {
#                                     "name": "Action",
#                                     "value": 113
#                                 },
#                                 {
#                                     "name": "History",
#                                     "value": 112
#                                 },
#                                 {
#                                     "name": "Mystery",
#                                     "value": 59
#                                 },
#                                 {
#                                     "name": "Sci-Fi",
#                                     "value": 59
#                                 },
#                                 {
#                                     "name": "Musical",
#                                     "value": 228
#                                 },
#                                 {
#                                     "name": "Thriller",
#                                     "value": 46
#                                 },
#                                 {
#                                     "name": "Film-Noir",
#                                     "value": 1
#                                 },
#                                 {
#                                     "name": "Adult",
#                                     "value": 3
#                                 }
#                             ]
#                         },
#                         {
#                             "name": "movie",
#                             "children": [
#                                 {
#                                     "name": "Romance",
#                                     "value": 10023
#                                 },
#                                 {
#                                     "name": "Documentary",
#                                     "value": 2161
#                                 },
#                                 {
#                                     "name": "Sport",
#                                     "value": 643
#                                 },
#                                 {
#                                     "name": "News",
#                                     "value": 3
#                                 },
#                                 {
#                                     "name": "Adventure",
#                                     "value": 5728
#                                 },
#                                 {
#                                     "name": "Action",
#                                     "value": 6444
#                                 },
#                                 {
#                                     "name": "Biography",
#                                     "value": 1271
#                                 },
#                                 {
#                                     "name": "Drama",
#                                     "value": 36838
#                                 },
#                                 {
#                                     "name": "Fantasy",
#                                     "value": 1776
#                                 },
#                                 {
#                                     "name": "Comedy",
#                                     "value": 20126
#                                 },
#                                 {
#                                     "name": "War",
#                                     "value": 2579
#                                 },
#                                 {
#                                     "name": "Crime",
#                                     "value": 8576
#                                 },
#                                 {
#                                     "name": "Family

# %%
#构建旭日图函数
def buildSunburst(title, data):
    sunburst=(
        Sunburst(
            init_opts=opts.InitOpts(height='950px'),
        )
        .add(
            'IMDB', data, radius=[0, '65%'], center=['400px','450px']
        )
        .set_series_opts(
            label_opts=opts.LabelOpts(formatter="{b}:{c}", position="outside")
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title=title),
        )
    )
    
    return sunburst

# %%
#第七步  可视化旭日图，请注意jupyter的可视化方式不一样
buildSunburst('IMDB', sunburstData).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1a38bc39c9594a52910db722cab2d3b9" style="width:900px; height:950px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1a38bc39c9594a52910db722cab2d3b9 = echarts.init(
#                     document.getElementById('1a38bc39c9594a52910db722cab2d3b9'), 'white', {renderer: 'canvas'});
#                 var option_1a38bc39c9594a52910db722cab2d3b9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "sunburst",
#             "name": "IMDB",
#             "data": [
#                 {
#                     "name": "short",
#                     "children": [
#                         {
#                             "name": "Documentary",
#                             "value": 1962
#                         },
#                         {
#                             "name": "Short",
#                             "value": 12675
#                         },
#                         {
#                             "name": "Animation",
#                             "value": 4063
#                         },
#                         {
#                             "name": "Comedy",
#                             "value": 6886
#                         },
#                         {
#                             "name": "Romance",
#                             "value": 514
#                         },
#                         {
#                             "name": "Sport",
#                             "value": 82
#                         },
#                         {
#                             "name": "News",
#                             "value": 19
#                         },
#                         {
#                             "name": "Drama",
#                             "value": 2501
#                         },
#                         {
#                             "name": "Fantasy",
#                             "value": 201
#                         },
#                         {
#                             "name": "Horror",
#                             "value": 128
#                         },
#                         {
#                             "name": "Biography",
#                             "value": 78
#                         },
#                         {
#                             "name": "Music",
#                             "value": 265
#                         },
#                         {
#                             "name": "War",
#                             "value": 285
#                         },
#                         {
#                             "name": "Crime",
#                             "value": 233
#                         },
#                         {
#                             "name": "Western",
#                             "value": 755
#                         },
#                         {
#                             "name": "Family",
#                             "value": 2314
#                         },
#                         {
#                             "name": "Adventure",
#                             "value": 303
#                         },
#                         {
#                             "name": "Action",
#                             "value": 113
#                         },
#                         {
#                             "name": "History",
#                             "value": 112
#                         },
#                         {
#                             "name": "Mystery",
#                             "value": 59
#                         },
#                         {
#                             "name": "Sci-Fi",
#                             "value": 59
#                         },
#                         {
#                             "name": "Musical",
#                             "value": 228
#                         },
#                         {
#                             "name": "Thriller",
#                             "value": 46
#                         },
#                         {
#                             "name": "Film-Noir",
#                             "value": 1
#                         },
#                         {
#                             "name": "Adult",
#                             "value": 3
#                         }
#                     ]
#                 },
#                 {
#                     "name": "movie",
#                     "children": [
#                         {
#                             "name": "Romance",
#                             "value": 10023
#                         },
#                         {
#                             "name": "Documentary",
#                             "value": 2161
#                         },
#                         {
#                             "name": "Sport",
#                             "value": 643
#                         },
#                         {
#                             "name": "News",
#                             "value": 3
#                         },
#                         {
#                             "name": "Adventure",
#                             "value": 5728
#                         },
#                         {
#                             "name": "Action",
#                             "value": 6444
#                         },
#                         {
#                             "name": "Biography",
#                             "value": 1271
#                         },
#                         {
#                             "name": "Drama",
#                             "value": 36838
#                         },
#                         {
#                             "name": "Fantasy",
#                             "value": 1776
#                         },
#                         {
#                             "name": "Comedy",
#                             "value": 20126
#                         },
#                         {
#                             "name": "War",
#                             "value": 2579
#                         },
#                         {
#                             "name": "Crime",
#                             "value": 8576
#                         },
#                         {
#                             "name": "Family",
#                             "value": 1938
#                         },
#                         {
#                             "name": "History",
#                             "value": 1746
#                         },
#                         {
#                             "name": "Sci-Fi",
#                             "value": 1413
#                         },
#                         {
#                             "name": "Thriller",
#                             "value": 3385
#                         },
#                         {
#                             "name": "Western",
#                             "value": 4862
#                         },
#                         {
#                             "name": "Mystery",
#                             "value": 3071
#                         },
#                         {
#                             "name": "Horror",
#                             "value": 3264
#                         },
#                         {
#                             "name": "Music",
#                             "value": 1802
#                         },
#                         {
#                             "name": "Animation",
#                             "value": 394
#                         },
#                         {
#                             "name": "Musical",
#                             "value": 2768
#                         },
